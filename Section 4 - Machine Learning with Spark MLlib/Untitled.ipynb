# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("MovieLens_Recommendations").getOrCreate()

# %%
ratings = (
    spark.read.csv(
        "ratings.csv",
        sep=",",
        header=True,
        quote='"',
        schema="userId INT, movieId INT, rating DOUBLE, timestamp INT",
    )
    .drop(col("timestamp"))
    .withColumnRenamed("userId", "user")
    .withColumnRenamed("movieId", "item")
)

# %%
ratings.show()
ratings.count()
# Out:
# +----+----+------+
# |user|item|rating|
# +----+----+------+
# |   1|   1|   4.0|
# |   1|   3|   4.0|
# |   1|   6|   4.0|
# |   1|  47|   5.0|
# |   1|  50|   5.0|
# |   1|  70|   3.0|
# |   1| 101|   5.0|
# |   1| 110|   4.0|
# |   1| 151|   5.0|
# |   1| 157|   5.0|
# |   1| 163|   5.0|
# |   1| 216|   5.0|
# |   1| 223|   3.0|
# |   1| 231|   5.0|
# |   1| 235|   4.0|
# |   1| 260|   5.0|
# |   1| 296|   3.0|
# |   1| 316|   3.0|
# |   1| 333|   5.0|
# |   1| 349|   4.0|
# +----+----+------+
# only showing top 20 rows
# 100836

# %%
from pyspark.ml.recommendation import ALS

# %%
rank = 10
max_iter = 25
seed = 0

als = ALS(rank=rank, maxIter=max_iter, seed=seed)
model = als.fit(ratings)

# %%
model.userFactors.orderBy("id").show(30, False)
# Out:
# +---+----------------------------------------------------------------------------------------------------------------------------+
# |id |features                                                                                                                    |
# +---+----------------------------------------------------------------------------------------------------------------------------+
# |1  |[-0.29646167, -1.0991681, 0.43098325, 0.11375476, 1.1953692, 0.15712161, 1.2840616, 0.75633204, 0.6297434, 0.1069835]       |
# |2  |[-0.49296665, -0.28051114, 0.33050418, -0.41401663, 1.1505803, 0.4131445, 1.1909525, 0.85643035, 0.15713352, 0.035587862]   |
# |3  |[-0.57693475, -0.45748603, 0.20840773, -1.19696, 0.43931463, 1.1464447, -0.21777278, 0.56207395, 0.40704304, -1.1016352]    |
# |4  |[0.23605551, -1.6480961, -0.84258175, 0.31882033, 0.58057207, 0.2083654, 0.5769176, -0.056165535, 1.0585331, 0.17286816]    |
# |5  |[-0.1288039, -1.0679277, -0.53117055, -0.120779835, 0.781204, -0.31552023, 0.7718545, 0.60959375, 0.95008653, 0.20257188]   |
# |6  |[-0.13982572, -1.0998781, -0.070626296, -0.43280563, 1.2036129, -0.24207206, 1.2341545, 0.31200078, -0.26984492, 0.36393407]|
# |7  |[-0.14684585, -0.98468477, -1.0284456, -0.5952816, 1.1248449, 0.48527375, 0.7149625, -0.15992822, 0.79938114, 0.04066239]   |
# |8  |[-0.41622663, -0.8184543, -0.16816035, -0.6254007, 0.46791115, 0.35056567, 1.2451411, 0.12607247, 0.6733596, 0.57873285]    |
# |9  |[-0.43105862, -1.3060657, 0.04998523, 0.41977012, 0.74690664, 0.5968505, 0.8299694, 0.29047596, 0.90853524, -0.28226212]    |
# |10 |[-0.52024275, -1.0965117, 0.021745576, 1.0248187, 0.77919835, -0.038222216, 1.2537892, -0.49311817, -0.4389199, 0.29253182] |
# |11 |[-1.0262959, -0.8926626, -0.020087045, 0.3500384, 0.9827721, -0.023535816, 1.2411473, -0.10456037, 0.46488544, 0.3288807]   |
# |12 |[-0.14599995, -0.68199474, -0.023727369, 0.43125024, 1.377851, 0.06865047, 1.8359492, 0.2569818, 0.14939786, 0.47049418]    |
# |13 |[-0.8795301, -0.83512, -0.34303185, 0.012868147, 1.1023579, 0.63801, 0.92282075, -0.10115685, 0.85746825, -0.02383041]      |
# |14 |[-0.29081637, -0.46781805, 0.3967043, -0.40399426, 0.6298057, -0.053979725, 1.5003382, 0.19729435, 0.11030304, 1.0678349]   |
# |15 |[-1.1115186, -0.8968156, -0.112483904, -0.18072331, 0.25593, -0.13986474, 1.3197118, -0.44110423, 0.5367063, 0.60601217]    |
# |16 |[-0.37336385, -0.811575, 0.05413287, -0.17974067, 0.7854222, 0.17052513, 0.7428318, 0.4962584, 0.8059932, 0.23458992]       |
# |17 |[-0.45675144, -1.1176322, 0.10058104, -0.21775065, 0.86098254, 0.44944263, 0.9889151, 0.24631612, 0.65579706, 0.21634734]   |
# |18 |[-0.5838015, -0.9644086, 0.031765245, -0.15400541, 0.8511715, 0.34508008, 0.93837696, 0.31174186, 0.5870261, 0.4335696]     |
# |19 |[-0.3820194, -1.1120096, -0.068746164, -0.08026704, 0.5332443, 0.36627966, 0.6712021, 0.6677764, 0.37614074, -0.1772263]    |
# |20 |[-0.10867017, -1.4609786, -0.18617831, 0.48896238, 1.0162301, -0.11441463, 0.7973065, 0.32598358, 0.7014867, 0.655267]      |
# |21 |[-0.4891336, -0.49932256, 0.093418255, -0.15248857, 1.2791617, 0.28116545, 1.3224967, -0.34321684, -0.25274312, 0.186656]   |
# |22 |[0.21190405, -0.039070357, -0.10907586, -1.2364964, 1.0031661, -1.0685561, 1.1138147, 0.64510536, 0.93021387, -0.19111401]  |
# |23 |[-0.7623933, -0.8581049, 0.082867905, -0.28016466, 0.7652002, -0.030904999, 0.3659022, 0.16408616, 0.94122714, 0.37390593]  |
# |24 |[-0.6096675, -0.9804018, 0.1939578, -0.21408029, 0.79319483, 0.31401032, 1.0227075, 0.2164802, 0.38246053, 0.24130173]      |
# |25 |[-0.77380747, -1.1761643, 0.33514348, 0.049962997, 1.1469411, 0.40160072, 0.9874786, 0.33397853, 0.4989018, 0.42448205]     |
# |26 |[-0.44081947, -0.7778299, -0.22389981, -0.14566462, 0.8990443, 0.5205952, 0.8418135, 0.25672913, 0.59231544, 0.15608789]    |
# |27 |[-0.4663219, -1.0833056, -0.4646029, 0.30262408, 0.8233899, -0.45070508, 1.3838711, -0.062366758, -0.06822362, 0.44336838]  |
# |28 |[-0.7193866, -0.9322587, 0.5927486, -0.35827866, 0.49201724, 0.09515034, 0.8519531, -0.10011509, 0.4114692, 0.08168893]     |
# |29 |[-0.8301243, -0.81905335, 0.11744291, 0.029564746, 1.0103762, 0.027073953, 1.0292792, 0.18158652, 0.7915706, 0.22945327]    |
# |30 |[-0.49758947, -1.2064581, 0.123838894, 0.090139955, 1.5179136, 0.39883465, 0.7914495, 0.3577355, 0.21136162, 0.48317128]    |
# +---+----------------------------------------------------------------------------------------------------------------------------+
# only showing top 30 rows

# %%
simple_test_data = [
    (1, 2), 
    (10, 3), 
    (10, 8), 
    (20, 4), 
    (9, 7), 
    (550, 235)
]

test = spark.createDataFrame(simple_test_data, "user INT, item INT")

# %%
test_prediction = model.transform(test)

# %%
test_prediction.show()
# Out:
# +----+----+----------+
# |user|item|prediction|
# +----+----+----------+
# |  10|   3|  1.957693|
# | 550| 235| 3.4253366|
# |  20|   4| 2.3973246|
# |  10|   8| 1.5874846|
# |   9|   7| 2.4595492|
# |   1|   2| 3.9841352|
# +----+----+----------+

# %%
predictions_in_pandas = test_prediction.toPandas()

# %%
print(predictions_in_pandas)
# Out:
#    user  item  prediction
# 0    10     3    2.246040
# 1   550   235    3.208731
# 2    20     4    2.438197
# 3    10     8    1.380121
# 4     9     7    2.920148
# 5     1     2    4.126770
